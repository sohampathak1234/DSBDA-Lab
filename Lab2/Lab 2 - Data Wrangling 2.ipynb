# %% [markdown]
# # Data Wrangling 2

# %%
import pandas as pd
import numpy as np
import random 
import statistics

# %%
sdf = pd.read_csv("StudentsPerformance.csv")
sdf
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none        72.0           72.0           74.0
# 1                 completed        69.0           90.0           88.0
# 2                      none        90.0           95.0           93.0
# 3                      none         NaN           57.0           44.0
# 4                      none        76.0           78.0           75.0
# ..                      ...         ...            ...            ...
# 995               completed        88.0           99.0           95.0
# 996                    none        62.0           55.0           55.0
# 997               completed        59.0           71.0            NaN
# 998               completed        68.0           78.0           77.0
# 999                    none        77.0           86.0           86.0
#
# [1000 rows x 8 columns]

# %%
sdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   963 non-null    float64
#  6   reading score                956 non-null    float64
#  7   writing score                962 non-null    float64
# dtypes: float64(3), object(5)
# memory usage: 62.6+ KB

# %%
sdf.isnull().sum()
# Out:
# gender                          0
# race/ethnicity                  0
# parental level of education     0
# lunch                           0
# test preparation course         0
# math score                     37
# reading score                  44
# writing score                  38
# dtype: int64

# %%
sdf.shape
# Out:
# (1000, 8)

# %%
sdf.size
# Out:
# 8000

# %%
sdf.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
sdf.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none        72.0           72.0           74.0
# 1               completed        69.0           90.0           88.0
# 2                    none        90.0           95.0           93.0
# 3                    none         NaN           57.0           44.0
# 4                    none        76.0           78.0           75.0
# 5                    none        71.0           83.0           78.0
# 6               completed        88.0           95.0           92.0
# 7                    none        40.0           43.0           39.0
# 8               completed        64.0           64.0           67.0
# 9                    none        38.0           60.0           50.0

# %%
sdf["math score"] = sdf['math score'].replace(np.NaN,sdf['math score'].mean())  #replacing nan value with mean
sdf['math score'].head()
# Out:
# 0    72.000000
# 1    69.000000
# 2    90.000000
# 3    66.127726
# 4    76.000000
# Name: math score, dtype: float64

# %%
sdf['reading score'].head(50)
# Out:
# 0     72.0
# 1     90.0
# 2     95.0
# 3     57.0
# 4     78.0
# 5     83.0
# 6     95.0
# 7     43.0
# 8     64.0
# 9     60.0
# 10    54.0
# 11    52.0
# 12    81.0
# 13    72.0
# 14    53.0
# 15    75.0
# 16    89.0
# 17    32.0
# 18    42.0
# 19    58.0
# 20    69.0
# 21    75.0
# 22    54.0
# 23    73.0
# 24    71.0
# 25    74.0
# 26    54.0
# 27    69.0
# 28    70.0
# 29     NaN
# 30    74.0
# 31    65.0
# 32    72.0
# 33    42.0
# 34    87.0
# 35    81.0
# 36    81.0
# 37    64.0
# 38    90.0
# 39    56.0
# 40     NaN
# 41    73.0
# 42    58.0
# 43    65.0
# 44    56.0
# 45    54.0
# 46    65.0
# 47    71.0
# 48    74.0
# 49    84.0
# Name: reading score, dtype: float64

# %%
sdf['reading score'] = sdf['reading score'].replace(np.NaN,sdf['reading score'].median())
sdf['reading score'].head(50)
# Out:
# 0     72.0
# 1     90.0
# 2     95.0
# 3     57.0
# 4     78.0
# 5     83.0
# 6     95.0
# 7     43.0
# 8     64.0
# 9     60.0
# 10    54.0
# 11    52.0
# 12    81.0
# 13    72.0
# 14    53.0
# 15    75.0
# 16    89.0
# 17    32.0
# 18    42.0
# 19    58.0
# 20    69.0
# 21    75.0
# 22    54.0
# 23    73.0
# 24    71.0
# 25    74.0
# 26    54.0
# 27    69.0
# 28    70.0
# 29    70.0
# 30    74.0
# 31    65.0
# 32    72.0
# 33    42.0
# 34    87.0
# 35    81.0
# 36    81.0
# 37    64.0
# 38    90.0
# 39    56.0
# 40    70.0
# 41    73.0
# 42    58.0
# 43    65.0
# 44    56.0
# 45    54.0
# 46    65.0
# 47    71.0
# 48    74.0
# 49    84.0
# Name: reading score, dtype: float64

# %%
sdf['writing score'].head(50)
# Out:
# 0     74.0
# 1     88.0
# 2     93.0
# 3     44.0
# 4     75.0
# 5     78.0
# 6     92.0
# 7     39.0
# 8     67.0
# 9     50.0
# 10    52.0
# 11    43.0
# 12    73.0
# 13    70.0
# 14    58.0
# 15    78.0
# 16    86.0
# 17     NaN
# 18    46.0
# 19    61.0
# 20    63.0
# 21    70.0
# 22    53.0
# 23    73.0
# 24    80.0
# 25    72.0
# 26    55.0
# 27    75.0
# 28    65.0
# 29     NaN
# 30    74.0
# 31    61.0
# 32    65.0
# 33    38.0
# 34    82.0
# 35    79.0
# 36    83.0
# 37    59.0
# 38    88.0
# 39    57.0
# 40    54.0
# 41    68.0
# 42    65.0
# 43    66.0
# 44    54.0
# 45    57.0
# 46    62.0
# 47    76.0
# 48    76.0
# 49    82.0
# Name: writing score, dtype: float64

# %%
sdf['writing score']=sdf['writing score'].replace(np.NaN,statistics.mode(sdf['writing score']))
sdf['writing score'].head(50)
# Out:
# 0     74.0
# 1     88.0
# 2     93.0
# 3     44.0
# 4     75.0
# 5     78.0
# 6     92.0
# 7     39.0
# 8     67.0
# 9     50.0
# 10    52.0
# 11    43.0
# 12    73.0
# 13    70.0
# 14    58.0
# 15    78.0
# 16    86.0
# 17    74.0
# 18    46.0
# 19    61.0
# 20    63.0
# 21    70.0
# 22    53.0
# 23    73.0
# 24    80.0
# 25    72.0
# 26    55.0
# 27    75.0
# 28    65.0
# 29    74.0
# 30    74.0
# 31    61.0
# 32    65.0
# 33    38.0
# 34    82.0
# 35    79.0
# 36    83.0
# 37    59.0
# 38    88.0
# 39    57.0
# 40    54.0
# 41    68.0
# 42    65.0
# 43    66.0
# 44    54.0
# 45    57.0
# 46    62.0
# 47    76.0
# 48    76.0
# 49    82.0
# Name: writing score, dtype: float64

# %%
#using Drop na
df1=pd.read_csv("StudentsPerformance.csv")
df1
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none        72.0           72.0           74.0
# 1                 completed        69.0           90.0           88.0
# 2                      none        90.0           95.0           93.0
# 3                      none         NaN           57.0           44.0
# 4                      none        76.0           78.0           75.0
# ..                      ...         ...            ...            ...
# 995               completed        88.0           99.0           95.0
# 996                    none        62.0           55.0           55.0
# 997               completed        59.0           71.0            NaN
# 998               completed        68.0           78.0           77.0
# 999                    none        77.0           86.0           86.0
#
# [1000 rows x 8 columns]

# %%
df1.isnull().sum()
# Out:
# gender                          0
# race/ethnicity                  0
# parental level of education     0
# lunch                           0
# test preparation course         0
# math score                     37
# reading score                  44
# writing score                  38
# dtype: int64

# %%
df1.dropna(inplace=True)

# %%
df1  #dropped the whole row having null value
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none        72.0           72.0           74.0
# 1                 completed        69.0           90.0           88.0
# 2                      none        90.0           95.0           93.0
# 4                      none        76.0           78.0           75.0
# 5                      none        71.0           83.0           78.0
# ..                      ...         ...            ...            ...
# 994                    none        63.0           63.0           62.0
# 995               completed        88.0           99.0           95.0
# 996                    none        62.0           55.0           55.0
# 998               completed        68.0           78.0           77.0
# 999                    none        77.0           86.0           86.0
#
# [885 rows x 8 columns]

# %%
#using fillna

df2=pd.read_csv('StudentsPerformance.csv')
df2.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none        72.0           72.0           74.0
# 1               completed        69.0           90.0           88.0
# 2                    none        90.0           95.0           93.0
# 3                    none         NaN           57.0           44.0
# 4                    none        76.0           78.0           75.0

# %%
df2['math score']=df2['math score'].fillna(0)
df2.isnull().sum()
# Out:
# gender                          0
# race/ethnicity                  0
# parental level of education     0
# lunch                           0
# test preparation course         0
# math score                      0
# reading score                  44
# writing score                  38
# dtype: int64

# %%
df2['reading score']=df2['reading score'].fillna(method='ffill')
df2['reading score']
# Out:
# 0      72.0
# 1      90.0
# 2      95.0
# 3      57.0
# 4      78.0
#        ...
# 995    99.0
# 996    55.0
# 997    71.0
# 998    78.0
# 999    86.0
# Name: reading score, Length: 1000, dtype: float64

# %%
df2.isnull().sum()
# Out:
# gender                          0
# race/ethnicity                  0
# parental level of education     0
# lunch                           0
# test preparation course         0
# math score                      0
# reading score                   0
# writing score                  38
# dtype: int64

# %%
df2['reading score']=df2['reading score'].interpolate(method='linear',limit_direction='forward',axis=0)
df2['reading score'].head()
# Out:
# 0    72.0
# 1    90.0
# 2    95.0
# 3    57.0
# 4    78.0
# Name: reading score, dtype: float64

# %%
sdf
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none   72.000000           72.0           74.0
# 1                 completed   69.000000           90.0           88.0
# 2                      none   90.000000           95.0           93.0
# 3                      none   66.127726           57.0           44.0
# 4                      none   76.000000           78.0           75.0
# ..                      ...         ...            ...            ...
# 995               completed   88.000000           99.0           95.0
# 996                    none   62.000000           55.0           55.0
# 997               completed   59.000000           71.0           74.0
# 998               completed   68.000000           78.0           77.0
# 999                    none   77.000000           86.0           86.0
#
# [1000 rows x 8 columns]

# %%
sdf['gender']=np.where(sdf['gender']=='female',0,1)
sdf['gender']
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 995    0
# 996    1
# 997    0
# 998    0
# 999    0
# Name: gender, Length: 1000, dtype: int32

# %%
sdf
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0         0        group B           bachelor's degree      standard
# 1         0        group C                some college      standard
# 2         0        group B             master's degree      standard
# 3         1        group A          associate's degree  free/reduced
# 4         1        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995       0        group E             master's degree      standard
# 996       1        group C                 high school  free/reduced
# 997       0        group C                 high school  free/reduced
# 998       0        group D                some college      standard
# 999       0        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none   72.000000           72.0           74.0
# 1                 completed   69.000000           90.0           88.0
# 2                      none   90.000000           95.0           93.0
# 3                      none   66.127726           57.0           44.0
# 4                      none   76.000000           78.0           75.0
# ..                      ...         ...            ...            ...
# 995               completed   88.000000           99.0           95.0
# 996                    none   62.000000           55.0           55.0
# 997               completed   59.000000           71.0           74.0
# 998               completed   68.000000           78.0           77.0
# 999                    none   77.000000           86.0           86.0
#
# [1000 rows x 8 columns]

# %%
#Normalizing the data
sdf = sdf.drop(['race/ethnicity', 'parental level of education','lunch', 'test preparation course'],axis=1)
sdf
# Out:
#      gender  math score  reading score  writing score
# 0         0   72.000000           72.0           74.0
# 1         0   69.000000           90.0           88.0
# 2         0   90.000000           95.0           93.0
# 3         1   66.127726           57.0           44.0
# 4         1   76.000000           78.0           75.0
# ..      ...         ...            ...            ...
# 995       0   88.000000           99.0           95.0
# 996       1   62.000000           55.0           55.0
# 997       0   59.000000           71.0           74.0
# 998       0   68.000000           78.0           77.0
# 999       0   77.000000           86.0           86.0
#
# [1000 rows x 4 columns]

# %%
#Scaling
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
sdf = pd.DataFrame(scaler.fit_transform(sdf), columns=sdf.columns)
sdf
# Out:
#      gender  math score  reading score  writing score
# 0       0.0    0.720000       0.662651       0.711111
# 1       0.0    0.690000       0.879518       0.866667
# 2       0.0    0.900000       0.939759       0.922222
# 3       1.0    0.661277       0.481928       0.377778
# 4       1.0    0.760000       0.734940       0.722222
# ..      ...         ...            ...            ...
# 995     0.0    0.880000       0.987952       0.944444
# 996     1.0    0.620000       0.457831       0.500000
# 997     0.0    0.590000       0.650602       0.711111
# 998     0.0    0.680000       0.734940       0.744444
# 999     0.0    0.770000       0.831325       0.844444
#
# [1000 rows x 4 columns]

# %%
#using boxplot
cols=['math score','reading score','writing score']
sdf.boxplot(cols)
# Out:
# <AxesSubplot:>

# %%
sdf2 = pd.read_csv('StudentsPerformance.csv')
sdf2 = sdf2.drop(['race/ethnicity', 'parental level of education','lunch', 'test preparation course'],axis=1)
sdf2
# Out:
#      gender  math score  reading score  writing score
# 0    female        72.0           72.0           74.0
# 1    female        69.0           90.0           88.0
# 2    female        90.0           95.0           93.0
# 3      male         NaN           57.0           44.0
# 4      male        76.0           78.0           75.0
# ..      ...         ...            ...            ...
# 995  female        88.0           99.0           95.0
# 996    male        62.0           55.0           55.0
# 997  female        59.0           71.0            NaN
# 998  female        68.0           78.0           77.0
# 999  female        77.0           86.0           86.0
#
# [1000 rows x 4 columns]

# %%
sdf2[sdf2['math score']<20]
# Out:
#      gender  math score  reading score  writing score
# 59   female         0.0           17.0           10.0
# 787  female        19.0           38.0           32.0
# 980  female         8.0           24.0           23.0

# %%
sdf2[sdf2['reading score']<20]
# Out:
#     gender  math score  reading score  writing score
# 59  female         0.0           17.0           10.0

# %%
sdf2[sdf2['writing score']<20]
# Out:
#      gender  math score  reading score  writing score
# 59   female         0.0           17.0           10.0
# 327    male        28.0           23.0           19.0
# 596    male        30.0           24.0           15.0

# %%
#importing matplotlib
import matplotlib.pyplot as plt
#using scatterplot 
scat=plt.subplot()
scat.scatter(sdf['reading score'],sdf['writing score'])
plt.show()

# %%
scat.set_xlabel('reading score')
scat.set_ylabel('Writing score')
plt.show()

# %%
np.where((sdf2['reading score']<20)&(sdf2['writing score']>1))
# Out:
# (array([59], dtype=int64),)

# %%
import scipy
from scipy import stats

# %%
z=np.abs(stats.zscore(sdf['math score']))
z
# Out:
# 0      3.951896e-01
# 1      1.932970e-01
# 2      1.606545e+00
# 3      7.471528e-16
# 4      6.643798e-01
#            ...
# 995    1.471950e+00
# 996    2.777858e-01
# 997    4.796784e-01
# 998    1.259994e-01
# 999    7.316773e-01
# Name: math score, Length: 1000, dtype: float64

# %%
threshhold=0.00001
#display outliers
sample_outliers=np.where(z<threshhold)
sample_outliers
# Out:
# (array([  3,  17,  52,  95, 104, 147, 180, 210, 248, 267, 301, 314, 341,
#         353, 377, 389, 415, 429, 447, 473, 498, 533, 586, 593, 602, 627,
#         650, 688, 729, 751, 777, 828, 845, 857, 909, 951, 976], dtype=int64),)

# %%
sdf2['math score'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sdf2['logmath']=np.log10(sdf2['math score'])
sdf2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#      gender  math score  reading score  writing score   logmath
# 0    female        72.0           72.0           74.0  1.857332
# 1    female        69.0           90.0           88.0  1.838849
# 2    female        90.0           95.0           93.0  1.954243
# 3      male         NaN           57.0           44.0       NaN
# 4      male        76.0           78.0           75.0  1.880814
# ..      ...         ...            ...            ...       ...
# 995  female        88.0           99.0           95.0  1.944483
# 996    male        62.0           55.0           55.0  1.792392
# 997  female        59.0           71.0            NaN  1.770852
# 998  female        68.0           78.0           77.0  1.832509
# 999  female        77.0           86.0           86.0  1.886491
#
# [1000 rows x 5 columns]
